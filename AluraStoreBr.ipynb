# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiaalvesdasilva/challenge_loja/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
loja_faturamento = loja['Preço'].sum()
print(loja_faturamento)
# Out:
# 1534509.12

# %%
soma_venda = 0

# %%
for venda in loja.Preço:
  soma_venda += (venda)
print(soma_venda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb9ba43b76cf> in <cell line: 0>()
#       1 for venda in loja.Preço:
# ----> 2   soma_venda += (venda)
#       3 print(soma_venda)
#
# NameError: name 'soma_venda' is not defined

# %%
loja2_faturamento = loja2['Preço'].sum()
print(loja2_faturamento)
# Out:
# 1488459.06

# %%
loja3_faturamento = loja3['Preço'].sum()
print(loja3_faturamento)
# Out:
# 1464025.03

# %%
loja4_faturamento = loja4['Preço'].sum()
print(loja4_faturamento)
# Out:
# 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
loja_categoria = loja[loja['Categoria do Produto']=='eletronicos']['Preço'].sum()
print(loja_categoria)
# Out:
# 572659.23

# %%
categoria = []
for item in loja['Categoria do Produto']:
  print(item)
# Out:
# eletronicos
# moveis
# brinquedos
# eletrodomesticos
# moveis
# brinquedos
# brinquedos
# eletrodomesticos
# eletrodomesticos
# brinquedos
# eletrodomesticos
# eletrodomesticos
# eletronicos
# utilidades domesticas
# esporte e lazer
# livros
# esporte e lazer
# brinquedos
# eletronicos
# brinquedos
# eletrodomesticos
# esporte e lazer
# esporte e lazer
# moveis
# livros
# utilidades domesticas
# utilidades domesticas
# instrumentos musicais
# esporte e lazer
# brinquedos
# eletrodomesticos
# brinquedos
# moveis
# esporte e lazer
# brinquedos
# esporte e lazer
# eletronicos
# moveis
# livros
# moveis
# eletronicos
# moveis
# brinquedos
# eletrodomesticos
# brinquedos
# esporte e lazer
# instrumentos musicais
# utilidades domesticas
# eletrodomesticos
# moveis
# eletronicos
# moveis
# eletronicos
# instrumentos musicais
# brinquedos
# utilidades domesticas
# eletronicos
# eletrodomesticos
# eletronicos
# brinquedos
# esporte e lazer
# moveis
# eletronicos
# livros
# moveis
# ...

# %%
categoria =[]
for item in loja['Categoria do Produto']:
  if item not in categoria:
    categoria.append(item)
print(categoria)
# Out:
# ['eletronicos', 'moveis', 'brinquedos', 'eletrodomesticos', 'utilidades domesticas', 'esporte e lazer', 'livros', 'instrumentos musicais']

# %%
categoria =[]
for item in loja['Categoria do Produto']:
  if item not in categoria:
    categoria.append(item)
    print([item,len(loja[loja['Categoria do Produto']== item])])
# Out:
# ['eletronicos', 448]
# ['moveis', 465]
# ['brinquedos', 324]
# ['eletrodomesticos', 312]
# ['utilidades domesticas', 171]
# ['esporte e lazer', 284]
# ['livros', 173]
# ['instrumentos musicais', 182]

# %%
lojas = [loja, loja2, loja3, loja4]


for i in range(len(lojas)):
  categoria =[]
  for item in lojas[i]['Categoria do Produto']:
    if item not in categoria:
      categoria.append(item)
      print(i,item,len(lojas[i][lojas[i]['Categoria do Produto']== item]))
  print('\n')
# Out:
# 0 eletrodomesticos 254
# 0 moveis 480
# 0 esporte e lazer 277
# 0 livros 187
# 0 eletronicos 451
# 0 instrumentos musicais 170
# 0 brinquedos 338
# 0 utilidades domesticas 201
#
#
# 1 moveis 442
# 1 instrumentos musicais 224
# 1 esporte e lazer 275
# 1 eletronicos 422
# 1 utilidades domesticas 181
# 1 brinquedos 313
# 1 eletrodomesticos 305
# 1 livros 197
#
#
# 2 eletrodomesticos 278
# 2 moveis 499
# 2 instrumentos musicais 177
# 2 esporte e lazer 277
# 2 eletronicos 451
# 2 brinquedos 315
# 2 utilidades domesticas 177
# 2 livros 185
#
#
# 3 eletrodomesticos 254
# 3 moveis 480
# 3 esporte e lazer 277
# 3 livros 187
# 3 eletronicos 451
# 3 instrumentos musicais 170
# 3 brinquedos 338
# 3 utilidades domesticas 201

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):

    media = sum(lojas[i]['Avaliação da compra']) / len(lojas[i])
    print(i, media)
# Out:
# 0 3.976685036032217
# 1 4.037303942348453
# 2 4.048325561678677
# 3 3.9957591178965224

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
lojas = [loja, loja2, loja3, loja4]
dados =[]

for i in range(len(lojas)):
   produtos = []

   for item in lojas[i]['Produto']:
    if item not in produtos:
      produtos.append(item)
      print(i,item, len(lojas[i][lojas[i]['Produto']==item]))
      dados.append([i,item, len(lojas[i][lojas[i]['Produto']==item])])
   print('\n')
# Out:
# 0 Assistente virtual 40
# 0 Mesa de jantar 40
# 0 Jogo de tabuleiro 43
# 0 Micro-ondas 60
# 0 Cadeira de escritório 46
# 0 Blocos de montar 56
# 0 Boneca bebê 40
# 0 Lava louças 48
# 0 Lavadora de roupas 47
# 0 Carrinho controle remoto 52
# 0 Geladeira 54
# 0 Fone de ouvido 50
# 0 Panela de pressão 35
# 0 Bicicleta 54
# 0 Ciência de dados com python 39
# 0 Bola de vôlei 42
# 0 Xadrez de madeira 49
# 0 TV Led UHD 4K 60
# 0 Copo térmico 54
# 0 Kit banquetas 44
# 0 Dashboards com Power BI 42
# 0 Faqueiro 52
# 0 Jogo de panelas 43
# 0 Bateria 53
# 0 Corda de pular 40
# 0 Fogão 45
# 0 Cama box 44
# 0 Impressora 54
# 0 Cômoda 56
# 0 Guarda roupas 60
# 0 Dinossauro Rex 40
# 0 Guitarra 47
# 0 Secadora de roupas 58
# 0 Sofá retrátil 46
# 0 Tablet ABXY 42
# 0 Cubo mágico 8x8 44
# 0 Jogo de copos 41
# 0 Modelagem preditiva 51
# 0 Celular Plus X42 49
# 0 Mochila 39
# 0 Bola de basquete 55
# 0 Headset 33
# 0 Poltrona 41
# 0 Violão 46
# 0 Iniciando em programação 41
# 0 Celular ABXY 33
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):

    media = sum(lojas[i]['Frete']) / len(lojas[i]['Frete'])
    print(i, (media))
# Out:
# 0 34.6918049155114
# 1 33.62194065817933
# 2 33.074464274117446
# 3 31.27899708184175

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):

  total = sum(lojas[i]['Frete'])
  print(i,(total))
# Out:
# 0 81837.9677956914
# 1 79314.15801264503
# 2 78022.66122264306
# 3 73755.87511898285

# %% [markdown]
# ## Análise Final

# %% [markdown]
# Foi dado o desafio de analisar 4 lojas ficticias para verirficar quais deveriam permanecer aberta e qual fechar.
# Na primeira analise de faturamento , pecebemos que a loja1 era que mais faturava, tendo um faturamento de 43 mil a mais do que a segunda loja que mais vende (loja2) , 66 mil a mais que a loja3 e 141 mil a mais do que a loja4.
# Ao analisar o frete , vimos que a loja1 tem um frete em reais acima das outras, entrentado, notamos que a porcentagem desse custo saia o mesmo 5% para todas as lojas.
# Notamos também que a média de avaliação da loja1 era a mesma que da loja4 porém , a loja4 tem um número muito menor de venda.
#
#
# Acreditamos, após analises de faturamento , frete e avaliações que a loja4 deve ser fechada

# %% [markdown]
# # Gráficos

# %%
faturamentos = [loja_faturamento, loja2_faturamento, loja3_faturamento, loja4_faturamento]
lojas = ["loja1", "loja2", "loja3", "loja4"]

plt.plot(lojas,faturamentos,'k--')

plt.plot(lojas, faturamentos, 'go')

plt.show()

# %%
faturamentos = [loja_faturamento, loja2_faturamento, loja3_faturamento, loja4_faturamento]
lojas = ["loja1", "loja2", "loja3", "loja4"]

plt.bar(lojas,faturamentos, color= 'red')

plt.xlabel('lojas')
plt.ylabel('faturamento')

plt.show()

# %%
faturamentos = [loja_faturamento, loja2_faturamento, loja3_faturamento, loja4_faturamento]
lojas = ["loja1", "loja2", "loja3", "loja4"]

fig = plt.figure(figsize=(10, 7))
plt.pie(faturamentos, labels=lojas)

plt.show()
